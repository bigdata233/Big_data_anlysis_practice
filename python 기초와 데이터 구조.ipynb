# %%
# 변수에 값을 할당
number = 10
greeting = "안녕하세요!"

# %%
print(number)
print(greeting)
# Out:
# 10
# 안녕하세요!

# %%
# 변수의 타입을 변경 # 동적 타이핑
number = "이제 문자열입니다"
print(number)
# Out:
# 이제 문자열입니다

# %%
# 변수 할당
a = 10
b = 3.3

# 기본 산술 연산자
print("a + b =", a + b)   #덧셈
print("a % b =", a % b)   #나눗셈 연산 후 나머지를 계산
print("a // b =", a // b)   #나눗셈의 몫을 정수로 반환
print("a ** b =", a ** b)   #거듭제곱 계산
# Out:
# a + b = 13.3
# a % b = 0.10000000000000053
# a // b = 3.0
# a ** b = 1995.2623149688789

# %%
x=15
print(x,"는 ", type(x), "형식입니다.", sep= '')
# Out:
# 15는 <class 'int'>형식입니다.

# %%
y=3.14159
print(y, "는 ", type(y), "형식입니다.", sep='')
# Out:
# 3.14159는 <class 'float'>형식입니다.

# %%
#여러 줄 문자열
ml_str = """This is
  a multi-line
      string"""

print(ml_str, type(ml_str))
# Out:
# This is
#   a multi-line
#       string <class 'str'>

# %%
#문자열 결합
greeting = "안녕" + " " + "파이썬!"
print("결합된 문자열:", greeting)

#문자열 반복
laugh = "하" * 4
print("반복된 문자열:", laugh)
# Out:
# 결합된 문자열: 안녕 파이썬!
# 반복된 문자열: 하하하하

# %%
a = [10, 20, 30, 40, 50]

# 인덱싱
print("첫 번째 요소:", a[0])  #10
print("마지막 요소:", a[-1])  #50

# 슬라이싱(a[start:end:step])
print("처음 두 개 요소:", a[:2])  #[10, 20]
print("중간 세 개 요소:", a[1:4])  #[20, 30, 40]
print("모든 요소(1개씩 건너뛰기):", a[::2]) #[10, 30, 50]
# Out:
# 첫 번째 요소: 10
# 마지막 요소: 50
# 처음 두 개 요소: [10, 20]
# 중간 세 개 요소: [20, 30, 40]
# 모든 요소(1개씩 건너뛰기): [10, 30, 50]

# %%
# 기존 요소 변경
fruits = ["apple", "banana"]

fruits[1] = "orange"
print("변경 된 리스트:", fruits)
# Out:
# 변경 된 리스트: ['apple', 'orange']

# %%
a = (10, 20, 30)

# 인덱싱
print("첫번째 좌표:", a[0])

# 슬라이싱
print("마지막 두 개 좌표:", a[1:])
# Out:
# 첫번째 좌표: 10
# 마지막 두 개 좌표: (20, 30)

# %%
fruits = ("apple", "banana", "cherry")

# 튜플의 요소를 변경 시도 -> TypeError 발생

fruits[1] = "orange"
print("변경 후 튜플:", fruits) # 실행되지 않음
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-c73114a13da9> in <cell line: 0>()
#       3 # 튜플의 요소를 변경 시도 -> TypeError 발생
#       4
# ----> 5 fruits[1] = "orange"
#       6 print("변경 후 튜플:", fruits) # 실행되지 않음
#
# TypeError: 'tuple' object does not support item assignment

# %%
person = {
    'name' : 'John',
    'age' : '30',
    'city' : 'New York'
    }

print("Person:", person)
# Out:
# Person: {'name': 'John', 'age': '30', 'city': 'New York'}

# %%
# 딕셔너리 값을 가져오기

print("이름:", person['name'])
print("나이:", person['age'])
print("도시:", person['city'])
# Out:
# 이름: John
# 나이: 30
# 도시: New York

# %%
# 집합
fruits = {'apple', 'banana', 'cherry', 'apple'}
print("Fruits set:", fruits)  #중복 'apple'은 제거됨

# 빈 집합 생성
empty_set = set()
print("Empty set:", empty_set)
# Out:
# Fruits set: {'banana', 'apple', 'cherry'}
# Empty set: set()

# %%
# 메서드 활용

# 요소 추가
fruits.add('orange')
print("After adding orange", fruits)

# 요소 삭제
fruits.remove('banana')
print("After removing banana:", fruits)
# Out:
# After adding orange {'apple', 'cherry', 'orange'}

# %%
# 집합 간 연산
other_fruits = {'berry', 'cherry'}
union_fruits = fruits.union(other_fruits)
intersection_fruits = fruits.intersection(other_fruits)

print("Union of fruits:", union_fruits)
print("Intersection of fruits:", intersection_fruits)
# Out:
# Union of fruits: {'apple', 'cherry', 'berry', 'orange'}
# Intersection of fruits: {'cherry'}

# %%
# 논리형 값의 사용
p = True
q = False
print(p, type(p))
print(q, type(q))

print(p+p)
# Out:
# True <class 'bool'>
# False <class 'bool'>
# 2

# %%
# 논리형 값은 조건문의 결과로 생성되기도 한다.

is_active = True
is_greater = 10 > 5   #True 반환
is_equal = (10==5)    #False 반환

print("Is_active:", is_active)
print("Is 10 greater than 5?:", is_greater)
print("Is 10 equal to 5?:", is_equal)
# Out:
# Is_active: True
# Is 10 greater than 5?: True
# Is 10 equal to 5?: False

# %%
# 논리 AND 연산
print("True and False:", True and False)
# 논리 OR 연산
print("True or False:", True or False)
# 논리 NOT 연산
print("not True:", not True)
# Out:
# True and False: False
# True or False: True
# not True: False

# %%
# 조건문에서의 논리형 사용

a=3
if (a==2):
  print("a는 2와 같습니다.")
else:
  print("a는 2와 같지 않습니다.")
# Out:
# a는 2와 같지 않습니다.

# %%
# 숫자형을 문자열형으로 변환
num = 123
str_num = str(num)
print("문자열:", str_num, type(str_num))

# 문자열형을 숫자형(실수)으로 변환
num_again = float(str_num)
print("숫자형:", num_again, type(num_again))
# Out:
# 문자열: 123 <class 'str'>
# 숫자형: 123.0 <class 'float'>

# %%
# 리스트와 튜플 변환
lst = [1,2,3]
print("리스트", lst)
tup = tuple(lst)
print("튜플:", tup)
# Out:
# 리스트 [1, 2, 3]
# 튜플: (1, 2, 3)

# %%
# 집합 -> 딕셔너리 변환(원칙불가)

set_example = {'a', 'b', 'c'}

# 딕셔너리로 변환 시, 일반적으로 집합 요소를 키 또는 값으로 사용

dict_from_set = {key: True for key in set_example}
print("Dictionary from set:", dict_from_set)
# Out:
# Dictionary from set: {'b': True, 'a': True, 'c': True}

# %%
# 숫자를 논리형으로 변환
zero = 0
non_zero = 7
bool_from_zero = bool(zero)
bool_from_non_zero = bool(non_zero)
print("0을 논리형으로 바꾸면:", bool_from_zero)
print("7을 논리형으로 바꾸면:", bool_from_non_zero)

# 논리형을 숫자로 변환
true_bool = True
false_bool = False
int_from_true = int(true_bool)
int_from_false = int(false_bool)
print("True는 숫자로:", int_from_true)
print("False는 숫자로:", int_from_false)
# Out:
# 0을 논리형으로 바꾸면: False
# 7을 논리형으로 바꾸면: True
# True는 숫자로: 1
# False는 숫자로: 0

# %%
# 논리형을 문자열로 변환
str_from_true = str(true_bool)
str_from_false = str(false_bool)
print("True는 문자열로:", str_from_true)
print("False는 문자열로:", str_from_false)

# 문자열을 논리형으로 변환 (비어있지 않으면 무조건 참)
str_true = "True"
str_false = "False"
bool_from_str_true = bool(str_true)
bool_from_str_false = bool(str_false)
print("'True'는 논리형으로 바꾸면:", bool_from_str_true)
print("'False'는 논리형으로 바꾸면:", bool_from_str_false)
# Out:
# True는 문자열로: True
# False는 문자열로: False
# 'True'는 논리형으로 바꾸면: True
# 'False'는 논리형으로 바꾸면: True
